# %% [markdown]
# # 1. Install MarkLLM

# %%
# !pip install -r requirements.txt
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

download_models = True

opt_path = "models/opt-1.3b"
llama_path = "models/llama-7b"
nllb_path = "models/nllb-200-distilled-600M"
bert_large_uncased_path = "models/compositional-bert-large-uncased/"
t5_path = "models/t5-v1_1-xxl"
starcoder_path = "models/starcoder"

if download_models:
    # !pip install -U huggingface-hub
    # !huggingface-cli login --token "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"
    # !huggingface-cli download --resume-download facebook/opt-1.3b --local-dir {opt_path}
    # !huggingface-cli download --resume-download princeton-nlp/Sheared-LLaMA-1.3B --local-dir {llama_path}
    # !huggingface-cli download --resume-download facebook/nllb-200-distilled-600M --local-dir {nllb_path}
    # !huggingface-cli download --resume-download google-bert/bert-large-uncased --local-dir {bert_large_uncased_path}
    # !huggingface-cli download --resume-download google/t5-v1_1-xxl --local-dir {t5_path}
    # !huggingface-cli download --resume-download bigcode/starcoder --local-dir {starcoder_path}
# Out:
# Requirement already satisfied: transformers in c:\users\kharl\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 1)) (4.32.0)
# Requirement already satisfied: datasets in c:\users\kharl\appdata\roaming\python\python311\site-packages (from -r requirements.txt (line 2)) (2.14.4)
# Requirement already satisfied: nltk in c:\python311\lib\site-packages (from -r requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: jieba in c:\python311\lib\site-packages (from -r requirements.txt (line 4)) (0.42.1)
# Collecting accelerate (from -r requirements.txt (line 5))
#   Using cached accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: SentencePiece in c:\python311\lib\site-packages (from -r requirements.txt (line 6)) (0.1.99)
# Collecting openai==0.28 (from -r requirements.txt (line 7))
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Collecting Cython (from -r requirements.txt (line 8))
#   Using cached Cython-3.0.11-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: Pillow==9.4.0 in c:\python311\lib\site-packages (from -r requirements.txt (line 9)) (9.4.0)
# Collecting sacrebleu (from -r requirements.txt (line 10))
#   Using cached sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: sentence-transformers in c:\python311\lib\site-packages (from -r requirements.txt (line 11)) (2.2.2)
# Requirement already satisfied: networkx in c:\python311\lib\site-packages (from -r requirements.txt (line 12)) (3.0)
# Collecting translate (from -r requirements.txt (line 13))
#   Using cached translate-3.6.1-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting tiktoken (from -r requirements.txt (line 14))
#   Using cached tiktoken-0.8.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting jupyter (from -r requirements.txt (line 15))
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib in c:\python311\lib\site-packages (from -r requirements.txt (line 16)) (3.7.1)
# Requirement already satisfied: requests>=2.20 in c:\python311\lib\site-packages (from openai==0.28->-r requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\kharl\appdata\roaming\python\python311\site-packages (from openai==0.28->-r requirements.txt (line 7)) (4.66.1)
# Requirement already satisfied: aiohttp in c:\users\kharl\appdata\roaming\python\python311\site-packages (from openai==0.28->-r requirements.txt (line 7)) (3.10.10)
# Requirement already satisfied: filelock in c:\python311\lib\site-packages (from transformers->-r requirements.txt (line 1)) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers->-r requirements.txt (line 1))
#   Using cached huggingface_hub-0.27.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from transformers->-r requirements.txt (line 1)) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from transformers->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\python311\lib\site-packages (from transformers->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\python311\lib\site-packages (from transformers->-r requirements.txt (line 1)) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\python311\lib\site-packages (from transformers->-r requirements.txt (line 1)) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\python311\lib\site-packages (from transformers->-r requirements.txt (line 1)) (0.5.2)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from datasets->-r requirements.txt (line 2)) (17.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from datasets->-r requirements.txt (line 2)) (0.3.7)
# Requirement already satisfied: pandas in c:\users\kharl\appdata\roaming\python\python311\site-packages (from datasets->-r requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: xxhash in c:\python311\lib\site-packages (from datasets->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\kharl\appdata\roaming\python\python311\site-packages (from datasets->-r requirements.txt (line 2)) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in c:\python311\lib\site-packages (from fsspec[http]>=2021.11.1->datasets->-r requirements.txt (line 2)) (2023.6.0)
# Requirement already satisfied: click in c:\python311\lib\site-packages (from nltk->-r requirements.txt (line 3)) (8.1.3)
# Requirement already satisfied: joblib in c:\python311\lib\site-packages (from nltk->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: psutil in c:\users\kharl\appdata\roaming\python\python311\site-packages (from accelerate->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in c:\python311\lib\site-packages (from accelerate->-r requirements.txt (line 5)) (2.0.1+cu118)
# Requirement already satisfied: portalocker in c:\python311\lib\site-packages (from sacrebleu->-r requirements.txt (line 10)) (3.1.1)
# Requirement already satisfied: tabulate>=0.8.9 in c:\python311\lib\site-packages (from sacrebleu->-r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: colorama in c:\users\kharl\appdata\roaming\python\python311\site-packages (from sacrebleu->-r requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: lxml in c:\python311\lib\site-packages (from sacrebleu->-r requirements.txt (line 10)) (5.3.0)
# Requirement already satisfied: torchvision in c:\python311\lib\site-packages (from sentence-transformers->-r requirements.txt (line 11)) (0.15.2)
# Requirement already satisfied: scikit-learn in c:\users\kharl\appdata\roaming\python\python311\site-packages (from sentence-transformers->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: scipy in c:\users\kharl\appdata\roaming\python\python311\site-packages (from sentence-transformers->-r requirements.txt (line 11)) (1.11.2)
# Requirement already satisfied: libretranslatepy==2.1.1 in c:\python311\lib\site-packages (from translate->-r requirements.txt (line 13)) (2.1.1)
# Collecting notebook (from jupyter->-r requirements.txt (line 15))
#   Using cached notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->-r requirements.txt (line 15))
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->-r requirements.txt (line 15))
#   Using cached nbconvert-7.16.5-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in c:\users\kharl\appdata\roaming\python\python311\site-packages (from jupyter->-r requirements.txt (line 15)) (6.23.2)
# Collecting ipywidgets (from jupyter->-r requirements.txt (line 15))
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting jupyterlab (from jupyter->-r requirements.txt (line 15))
#   Using cached jupyterlab-4.3.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 16)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 16)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 16)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 16)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 16)) (2.8.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 7)) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 7)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from aiohttp->openai==0.28->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python311\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers->-r requirements.txt (line 1)) (4.6.3)
# Requirement already satisfied: six>=1.5 in c:\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 16)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 7)) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests>=2.20->openai==0.28->-r requirements.txt (line 7)) (2023.5.7)
# Requirement already satisfied: sympy in c:\python311\lib\site-packages (from torch>=1.10.0->accelerate->-r requirements.txt (line 5)) (1.12)
# Requirement already satisfied: jinja2 in c:\python311\lib\site-packages (from torch>=1.10.0->accelerate->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (8.14.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (1.5.6)
# Requirement already satisfied: pyzmq>=20 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter->-r requirements.txt (line 15)) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\python311\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 15)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\python311\lib\site-packages (from ipywidgets->jupyter->-r requirements.txt (line 15)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 15)) (3.0.38)
# Requirement already satisfied: pygments in c:\users\kharl\appdata\roaming\python\python311\site-packages (from jupyter-console->jupyter->-r requirements.txt (line 15)) (2.15.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=40.8.0 in c:\python311\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 15)) (65.5.0)
# Collecting beautifulsoup4 (from nbconvert->jupyter->-r requirements.txt (line 15))
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 15))
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter->-r requirements.txt (line 15))
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter->-r requirements.txt (line 15))
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in c:\python311\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\python311\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 15)) (3.1.0)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->-r requirements.txt (line 15))
#   Using cached nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->-r requirements.txt (line 15))
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python311\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 15)) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\python311\lib\site-packages (from pandas->datasets->-r requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python311\lib\site-packages (from pandas->datasets->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: pywin32>=226 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from portalocker->sacrebleu->-r requirements.txt (line 10)) (306)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python311\lib\site-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 11)) (3.1.0)
# Requirement already satisfied: webencodings in c:\python311\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 15)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\python311\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 15)) (1.4.0)
# Collecting anyio (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: backcall in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\kharl\appdata\roaming\python\python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (0.6.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 15)) (3.6.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jupyter_events-0.11.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: overrides>=5.0 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (1.8.3)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in c:\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (1.8.0)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\python311\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 15)) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\kharl\appdata\roaming\python\python311\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 15)) (0.2.6)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from yarl<2.0,>=1.12.0->aiohttp->openai==0.28->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\python311\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 15)) (2.6)
# Requirement already satisfied: mpmath>=0.19 in c:\python311\lib\site-packages (from sympy->torch>=1.10.0->accelerate->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\python311\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (0.8.3)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\python311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 15)) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\python311\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (0.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\kharl\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 15)) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: uri-template in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\python311\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\python311\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (1.17.1)
# Requirement already satisfied: pycparser in c:\python311\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (2.22)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15))
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\python311\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 15)) (2.9.0.20241206)
# Using cached openai-0.28.0-py3-none-any.whl (76 kB)
# Using cached accelerate-1.2.1-py3-none-any.whl (336 kB)
# Using cached Cython-3.0.11-cp311-cp311-win_amd64.whl (2.8 MB)
# Using cached sacrebleu-2.5.1-py3-none-any.whl (104 kB)
# Using cached translate-3.6.1-py2.py3-none-any.whl (12 kB)
# Using cached tiktoken-0.8.0-cp311-cp311-win_amd64.whl (884 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyterlab-4.3.4-py3-none-any.whl (11.7 MB)
# Using cached nbconvert-7.16.5-py3-none-any.whl (258 kB)
# Using cached notebook-7.3.2-py3-none-any.whl (13.2 MB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached anyio-4.8.0-py3-none-any.whl (96 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached json5-0.10.0-py3-none-any.whl (34 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.11.0-py3-none-any.whl (19 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Installing collected packages: terminado, referencing, jupyterlab-pygments, jsonpointer, json5, h11, fqdn, defusedxml, Cython, bleach, beautifulsoup4, babel, async-lru, anyio, translate, tiktoken, sacrebleu, jupyter-server-terminals, jsonschema-specifications, huggingface-hub, httpcore, arrow, argon2-cffi-bindings, openai, jsonschema, isoduration, httpx, argon2-cffi, accelerate, nbformat, ipywidgets, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# WARNING: Ignoring invalid distribution ~uggingface-hub (C:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~uggingface-hub (C:\Python311\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Python311\\share\\jupyter'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in c:\python311\lib\site-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in c:\python311\lib\site-packages (0.15.2)
# Requirement already satisfied: torchaudio in c:\python311\lib\site-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in c:\python311\lib\site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\python311\lib\site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in c:\python311\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\python311\lib\site-packages (from torch) (3.0)
# Requirement already satisfied: jinja2 in c:\python311\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in c:\users\kharl\appdata\roaming\python\python311\site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: requests in c:\python311\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\python311\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python311\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests->torchvision) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\python311\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: Ignoring invalid distribution ~uggingface-hub (C:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~uggingface-hub (C:\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting huggingface-hub
#   Using cached huggingface_hub-0.27.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in c:\python311\lib\site-packages (from huggingface-hub) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\python311\lib\site-packages (from huggingface-hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from huggingface-hub) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\python311\lib\site-packages (from huggingface-hub) (6.0)
# Requirement already satisfied: requests in c:\python311\lib\site-packages (from huggingface-hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\kharl\appdata\roaming\python\python311\site-packages (from huggingface-hub) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python311\lib\site-packages (from huggingface-hub) (4.6.3)
# Requirement already satisfied: colorama in c:\users\kharl\appdata\roaming\python\python311\site-packages (from tqdm>=4.42.1->huggingface-hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests->huggingface-hub) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests->huggingface-hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests->huggingface-hub) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python311\lib\site-packages (from requests->huggingface-hub) (2023.5.7)
# Using cached huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
# Installing collected packages: huggingface-hub
# WARNING: Ignoring invalid distribution ~uggingface-hub (C:\Python311\Lib\site-packages)
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~uggingface-hub (C:\Python311\Lib\site-packages)
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Python311\\Scripts\\huggingface-cli.exe' -> 'C:\\Python311\\Scripts\\huggingface-cli.exe.deleteme'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Traceback (most recent call last):
#   File "C:\Python311\Lib\site-packages\huggingface_hub\utils\_http.py", line 406, in hf_raise_for_status
#     response.raise_for_status()
#   File "C:\Python311\Lib\site-packages\requests\models.py", line 1021, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Python311\Lib\site-packages\huggingface_hub\hf_api.py", line 1633, in whoami
#     hf_raise_for_status(r)
#   File "C:\Python311\Lib\site-packages\huggingface_hub\utils\_http.py", line 477, in hf_raise_for_status
#     raise _format(HfHubHTTPError, str(e), response) from e
# huggingface_hub.errors.HfHubHTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/whoami-v2 (Request ID: Root=1-6789443a-3e889ac0496915cb58eef9ca;6b2fe06a-e213-4343-b165-196e4d68313b)
#
# Invalid username or password.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Python311\Scripts\huggingface-cli.exe\__main__.py", line 7, in <module>
#   File "C:\Python311\Lib\site-packages\huggingface_hub\commands\huggingface_cli.py", line 57, in main
#     service.run()
#   File "C:\Python311\Lib\site-packages\huggingface_hub\commands\user.py", line 153, in run
#     login(
#   File "C:\Python311\Lib\site-packages\huggingface_hub\utils\_deprecation.py", line 101, in inner_f
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\huggingface_hub\utils\_deprecation.py", line 31, in inner_f
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\huggingface_hub\_login.py", line 126, in login
#     _login(token, add_to_git_credential=add_to_git_credential)
#   File "C:\Python311\Lib\site-packages\huggingface_hub\_login.py", line 404, in _login
#     token_info = whoami(token)
#                  ^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\huggingface_hub\utils\_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\huggingface_hub\hf_api.py", line 1635, in whoami
#     raise HTTPError(
# requests.exceptions.HTTPError: Invalid user token. If you didn't pass a user token, make sure you are properly logged in by executing `huggingface-cli login`, and if you did pass a user token, double-check it's correct.
# D:\uni\sem9\IPOW\MarkLLM-pwr\models\opt-1.3b
# C:\Python311\Lib\site-packages\huggingface_hub\file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# Fetching 12 files: 100%|██████████| 12/12 [00:00<00:00, 334.61it/s]

# %% [markdown]
# # 2. Watermaring Algorithm Invocation

# %%
import torch
import json
from watermark.auto_watermark import AutoWatermark
from utils.transformers_config import TransformersConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load data
with open('dataset/c4/processed_c4.json', 'r') as f:
    lines = f.readlines()
item = json.loads(lines[0])
prompt = item['prompt']
print(prompt)
natural_text = item['natural_text']
print(f'natural_text === {natural_text}')


def test_algorithm(algorithm_name):
    # Check algorithm name
    assert algorithm_name in ['KGW', 'Unigram', 'SWEET', 'EWD', 'SIR', 'XSIR', 'UPV', 'EXP', 'EXPEdit', 'Custom']

    # Device
    device = "cuda" if torch.cuda.is_available() else "cpu"

    # Transformers config
    transformers_config = TransformersConfig(model=AutoModelForCausalLM.from_pretrained(opt_path).to(device),
                                            tokenizer=AutoTokenizer.from_pretrained(opt_path),
                                            vocab_size=50272,
                                            device=device,
                                            max_new_tokens=200,
                                            min_length=230,
                                            do_sample=True,
                                            no_repeat_ngram_size=4)

    # Load watermark algorithm
    myWatermark = AutoWatermark.load(f'{algorithm_name}', algorithm_config=f'config/{algorithm_name}.json', transformers_config=transformers_config)


    prompt = '''
    public static void checkNumber(int number) {
        if (number > 0) {
            System.out.println("The number is positive.");
        }
        
        if (number < 0) {
            System.out.println("The number is negative.");
        }
        
        if (number == 0) {
            System.out.println("The number is zero.");
        }
    }
    '''
    

    # Generate text
    watermarked_text = myWatermark.generate_watermarked_text(prompt)
    unwatermarked_text = myWatermark.generate_unwatermarked_text(prompt)

    # Detect
    detect_result1 = myWatermark.detect_watermark(watermarked_text)
    detect_result2 = myWatermark.detect_watermark(unwatermarked_text)
    detect_result3 = myWatermark.detect_watermark(prompt)

    print("LLM-generated watermarked text:")
    print(watermarked_text)
    print('\n')
    print(detect_result1)
    print('\n')

    print("LLM-generated unwatermarked text:")
    print(unwatermarked_text)
    print('\n')
    print(detect_result2)
    print('\n')

    print("Natural text:")
    print(prompt)
    print('\n')
    print(detect_result3)
# Out:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems
# natural_text === .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security

# %%
test_algorithm('Custom')
# Out:
# LLM-generated watermarked text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#      int number = checkNumber(0, 1);
#   void system (System.out) {
# {
# // Error, something went wrong, System can't find the right position for
# // your output. Check the stack to make sure the right
# // one was used, then send print() for more info.
# (System.out.debug("input: input: ")); // System can't read in your string
# //
# // getString = getString(0);
# // Get out everything on your stack including
# // getNumber(0) and print the result.
# outString = getNumber(number);
# while (System.noEmpty()) {
# // Print strings, if no error, then they're all present
# outString[0] = " "++ number;
# outString.writeLine("\0\0\";);
# outString["{0}");
# outString[]=getNumber(number). "\n";
#
#
# {'is_watermarked': True, 'score': 6.07634357319533}
#
#
# LLM-generated unwatermarked text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#      return 0;
#  ?>
#   </pre>
#
# References
# http://www.linuxquestions.com/LinuxQuestions/viewtopic.php?t=1496
#
# Further reading
# AUTHOR DETAILS:
#
# MOSTLY UPDATED VERTUAL (2007), WITH SOME ADDITIONAL BACKPLACES (2004),
# AUTHORS:
#
# David K. B. and Mark O. Jones
# P. O. BOX:
#
# 87130
#
# PAPERS AND BLOGS:
# -
# http://hacked.hackers.com/newsletter/2007-07/
#
# http://linuxquestionsandcontroversialnews.com/2007/07/
# (http://linuxandbacon.me/)
#
# http:/code/users/dabbsh.html
#
# http.i.imgur.com
#
# <code>
#
#
# {'is_watermarked': False, 'score': -1.5275252316519465}
#
#
# Natural text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#
#
#
# {'is_watermarked': False, 'score': -4.142857142857143}

# %%
test_algorithm('KGW')
# Out:
# LLM-generated watermarked text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#      END if statement
#    } else if statement
#
# #include<math.h>
#
# #define MAXCAL_INFLUENCE 0
#
# #endif
#
# #endfor
#
# #class CheckNumber implements CheckNumber
#
# #else if #include
# #implement CheckNumber
# #implements checkNumber
# #endif
#
#
# {'is_watermarked': False, 'score': -3.486407715642266}
#
#
# LLM-generated unwatermarked text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#      return false;
# }
# }
#
# Another way to use this system is with the function getNumber($n).
#
# #include <string.h>
# void getNumber(string number) {
#
#    public int number;
#    public string string; // or float
#    }
#
#    return string;
# }
#
#
# {'is_watermarked': False, 'score': -5.125}
#
#
# Natural text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#
#
#
# {'is_watermarked': False, 'score': -6.984538909891174}

# %%
test_algorithm('Unigram')
# Out:
# LLM-generated watermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems. The server software runs on Opteron processors and supports the Open Virtual Machine (OVM) software for virtualizing Linux on top of the operating systems to run on cluster servers and storage nodes. The storage software can run on Opterons and virtualizes on top of storage nodes and features support for the Linux-on- steroids (Loose Linux) software for running virtual servers directly on Linux nodes and the Open Directory (OD) software for supporting both file and block level shared storage for using IBM i servers and database nodes in Loose Linux-based networks. The Open Directory software can run both on Linux and on OS-level virtual machines.
#
# For use in Loose Directory networks, IBM provides IBM i storage controller drivers that support the use of NetBIOS to manage IBM mSeries and other IBM i servers in Loose directory networks. NetBIOS is an industry defined standard that can establish and secure accesses to IBM i servers by IBM i i servers running in Loose
#
#
# {'is_watermarked': True, 'score': 10.90350690750898}
#
#
# LLM-generated unwatermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems, providing a complete multi-vendor system for data centers. One of the key selling points of the new system is its compatibility with both IBM's Opensource and Windows-based Linux server families, according to IBM. IBM will also announce a new Intel-based Linux-powered server family, IBM said.
#
# While the cluster is currently in beta form, it will be available as a general-purpose solution with support for Windows XP and Linux versions 2.6, 2.7 and 3.0. The Opteron server supports both the T2 microprocessor or the T4 processor with additional features and performance enhancements. Some of the newer features on the Opteron include:
#
# Enhanced network performance
#
# Improved virtualization performance
#
# Enhanced storage management capabilities
#
# Improved application servers (think SQL Server for instance)
#
# Reduced memory requirements
#
# Enhanced system security (though Windows XP and OpenVMS can easily get onto the list as long as it's used
#
#
# {'is_watermarked': False, 'score': 0.06608186004550898}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': 0.282842712474619}

# %%
test_algorithm('SWEET')
# Out:
# LLM-generated watermarked text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#      void cleanup(int sum) {
#  System.out->println(sum);
#  }
#
# The object created using the class System.Object doesn't
# have attributes, so it can be instantiated as any object,
# or as any number of these objects:
#
# The second argument to system.out.prod.checkNumber is called "number".
# The class System.EnablesInotify allows the definition of
# system.out.num to take as an argument
# something (such as sum) that the method checkNumber has
# to test for before invoking the return function to make
# something happen (say, generate a system.out stream). This allows the
# prod methods of the class System to be extended so that checkNumber can also be
# extended with more code (e.g., for an error condition). The
# class System.Enums grants the method on checkNumber the ability to get
# a reference to an object with multiple internal objects
#
#
# {'is_watermarked': True, 'score': 5.357061993998872}
#
#
# LLM-generated unwatermarked text:
#
#     public static void checkNumber(int number) {
#         if (number > 0) {
#             System.out.println("The number is positive.");
#         }
#
#         if (number < 0) {
#             System.out.println("The number is negative.");
#         }
#
#         if (number == 0) {
#             System.out.println("The number is zero.");
#         }
#     }
#      // The result of this call is used here
#    }
#
#     [DETAIL]
#    If you are working with a function with a number as argument, it is preferable to do a full cast on the number to the int parameter before proceeding. For example, to use the sum() function:
# sum("9.87");
# This will only make use of the value 8.00 when operating on an int which is in the double range. The result, however, is 9.87, which isn't a proper operand for the sum operation.
#
# See also
#  C2::Check
#
# References
#
#
# {'is_watermarked': False, 'score': -0.5516772843673704}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': -3.2857142857142856}

# %%
test_algorithm('UPV')
# Out:
# LLM-generated watermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems.
#
# This week's Linux Foundation's Fusion Developer Conference has attracted thousands of people in Chicago, including Intel chief operating officer Paul Otellini, Microsoft senior vice president of Windows server technologies Greg Smith, IBM director of Enterprise Server Technologies Dave Miller, and more.
#
# One of the main topics is the latest Linux kernel 5.2, a change that IBM's Opternon-based servers will get early access to, although IBM and Microsoft have not specified which ones of its Opteron line of servers will get Linux 5.2. They will run it during the Fusion Developer Conference.
#
# Otellini, Smith, Miller and AMD senior manager of Linux, virtualisation, and cloud services Pat Cipoletti all talked extensively about Linux, although they did not get any chance to actually use Linux for development, as none of them had access to the latest, fully tested Linux kernel.
#
# But they had plenty of time to show off Opteron systems running Linux,
#
#
# {'is_watermarked': True, 'score': None}
#
#
# LLM-generated unwatermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems. Enterprise clients can be running the Opteron processors or other systems.
#
# "Open source is really just an evolution on Linux," said Scott Luskin, a senior analyst with the Yankee Group and co-author of a book on the subject, "Linux is Free Software: Can You Take It?"
#
# An Open Service Management Protocol
# RMSF is being developed by several companies, including Red Hat, IBM, Intel, HP, NetApp, SAP, Symantec and Oracle.
#
# The first open-source version of RMSF is due to be released in February 2005. It's compatible with the existing Open Service Management Suite from EMC and was developed together with Open Source Systems, a joint venture of Microsoft Corp. and the Linux Foundation. Microsoft has begun licensing the software, including RMSF, but has not yet released a source distribution.
#
# Microsoft had approached the Linux Foundation with a proposal to license the software it created for use in its open
#
#
# {'is_watermarked': False, 'score': None}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': None}

# %%
test_algorithm('EWD')
# Out:
# LLM-generated watermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems. Customers can choose a combination of the servers to run their Linux applications or Windows-based applications using the Linux Enterprise Server, which IBM's software runs on those servers. (Credit: IBM)
#
# By providing free enterprise applications that meet global business demands, Linux Enterprise Server consolidates the Linux-based OS and operating system, the Linux software toolset, the Linux clustering software and the Linux systems management (eBusiness) operating system into a single platform capable of delivering true enterprise-wide availability at high price points. The Linux Enterprise Server and the hardware are co-located with a Linux-based software that is easy to use. Customers can be assured of an effective response and quick response times when the Linux eServer 325 servers are in response, recovery and disaster recover modes. Customers can also deploy the Linux clustery software on-premise to manage the Linux clustered compute resources. Enterprise customers can deploy the Linux Enterprise Services Manager to automate their operations, deliver consistent availability and deliver centralized
#
#
# {'is_watermarked': True, 'score': 8.958285331726074}
#
#
# LLM-generated unwatermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems.
#
# The cluster will be used by Enterprise Network Management (ENM) and other clients to manage IBM's global portfolio of mainframe, virtualized and application services. It will also deliver end to end management services to manage the network, security and other systems throughout the entire global network, said Scott Cramer, executive vice president enterprise systems IT, IBM System x, a part of IBM.
#
# This new cluster will be based on IBM's "green" platform, a system design pattern, including design elements from all corners of the enterprise to support a single point of management, deployment and maintenance.
#
# ENM will be the new middleware layer for the cluster, and the system will operate on the ENM standard operating parameters. ENM will connect the various subsystems of the node together for remote configuration (and later, management) of systems as well as provisioning and migration of data and applications. The Enm middleware standard is part of IBM's Open-Xchange
#
#
# {'is_watermarked': False, 'score': -0.6892887949943542}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': 0.20103169977664948}

# %%
test_algorithm('SIR')
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at watermark/sir/model/compositional-bert-large-uncased/ and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.380 seconds.
# Prefix dict has been built successfully.
# LLM-generated watermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems.
#
# "Our agreement with IBM will enable us to offer solutions to our clients and partners in more remote locations," Mr Healy said.
#
# The eServer 325 has been an early development workhorse but has been more generally used to support customers who wanted to manage and analyse large computing loads. And IBM has suggested some will grow to include more applications and processing, which could be seen as more suited to cloud computing models.
#
# IBM said more information would be available in coming weeks on how organisations could access its cloud management software and its software for virtualising or transforming hardware. That software has been used to manage and deliver cloud computing with more conventional hardware virtualisation.
#
# Mr Healy suggested he was interested in taking advantage of opportunities where big IT organisations have to manage distributed computing needs and where some IT organisations could use software to turn hardware into software.
#
# He suggested companies interested in buying iVenture, which has the licence and intellectual property to deliver cloud computing, would
#
#
# {'is_watermarked': True, 'score': 0.4811487797967988}
#
#
# LLM-generated unwatermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems.
#
# The cluster is said to have a storage capacity of 4TB, with the system's data backed up on two external SAS arrays.
#
# Users receive support from the Cluster Services and Support team based in the UK. IBM plans to offer a cloud-based version of the system in the near future.
#
# "The value of the OpenStack cloud and the benefits of a hybrid cloud are really quite compelling," said Richard Ladd, managing director of IBM Cloud and Security. "The combination of workloads and services is also well supported; even though we'll get a very high level of value in the hybrid model, it's still very compelling in the OpenStack model."
#
# The system has been shown during the OpenStack Open World at CEDIA in Las Vegas, and is expected to ship later in the year.
#
# Other key vendors include Digital Storm, Citrix, HP, Hypercloud, IBM and Amazon. ®
#
# Sponsored: Minds Mastering
#
#
# {'is_watermarked': False, 'score': -0.08778629736966252}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': -0.026743621749673936}

# %%
test_algorithm('XSIR')
# Out:
# LLM-generated watermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems as well as open-source virtualization technology such as VMware and virtualX on top of it. The Opteron is a top-performing server for storage virtualization and management with a price-performance ratio that can be just as good as an Intel Xeon processor. The software can be installed and maintained on a range of data center hardware.
#
# IBM is also moving forward with a range of new storage components. CloudXtreme storage allows customers to quickly deploy storage solutions and has a variety of expansion and upgrade options, including a virtual disk array that runs like a conventional storage array with no upfront cost and that can run as an Amazon EBS volume.
#
# In addition, Cloud-based technology that runs Linux and Windows can be leveraged on CloudXtrememt for cloud-managed virtual machines. Cloud-based server management software that can be used for Linux and Windows virtual hosting can be leveraded on CloudMigrations with a virtual machine virtualization toolkit and
#
#
# {'is_watermarked': True, 'score': 0.5088497479020971}
#
#
# LLM-generated unwatermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems. It also uses software including OpenBenchmarking Toolkit, an open source benchmark suite available at the Open Source Initiative web site.
#
# When the cluster is in service mode, the servers can communicate with one another and with a single large storage file system, which can handle a file system containing millions of files, said Mark Dolan, chairman of the eServer Cluster Advisory Board and research director at the University of Massachusetts Amherst.
#
# The cluster will have access to a file system that will handle a file storage as large as 200 petabytes.
#
# "It's a huge deal," Dolan said.
#
# This is the second eServer cluster in five years. The first eServer cluster, known as the eServer 2000, was first announced in 2005 and came about because of a software flaw that was found in OpenBenchmark Testing Suite. Dolan said the OpenBenchmark program does not require the eServer cluster to be in service mode.
#
# More information
#
#
# {'is_watermarked': False, 'score': -0.024457372363537688}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': 0.08666713667151175}

# %%
test_algorithm('EXP')
# Out:
# LLM-generated watermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems. Lexmark finds itself in a unique position -- many of its systems run under agreement with HP and IBM. It has shops that can run its LPAR and injection technology but also manage systems that have been configured as LabVIEW systems. I met with Dorion Gibson, who is the VP of Strategy and International Marketing at Lexmark, to discuss the blending of HP and IBM components.
#
# David McCaffrey: Let's talk about LPAR and injection technology. What are they used for?
#
# Dorian Gibson: LPAR allows us to have a software solution inside a PLC that allows higher throughput. We can run larger APIs for analytical systems and that sort of thing. So that's what we call injection technology because we can adapt to any application data, through the technology that's been integrated with Analysis Services.
#
# You can run infrastructure services on a more capable LPAR if needed on top of your lot, which has also been an important trend. HP-UX and IBM
#
#
# {'is_watermarked': True, 'score': 3.3943527905198416}
#
#
# LLM-generated unwatermarked text:
# Cluster comprises IBM's Opteron-based eServer 325 server and systems management software and storage devices that can run Linux and Windows operating systems.
#
# Bundled in with the servers, the company's OpenScale i5 and i7 mainframe servers (available in configurations of one machine apiece) sport a 2U form factor with AMD Opteron 4200 series processors, IBM's X-Series high-density memory, and 16 gigabytes of memory. IBM also offers its System z370 series of 2-U and 3-U Linux boxes with X-Series memory.
#
# IBM did not divulge the purchase price during today's announcement, but the company didn't take long to highlight its promise of a 25-50 percent efficiency gain -- while improving system performance -- over the iSeries.
#
# According to the company -- which did not mention a target revenue figure -- Opteron servers also produce 20 percent fewer resources per watt than iSeries models. IBM's OpenScale technology also improves power management by integrating power conservation algorithms into the hardware.
#
# Operating System Compatibility
#
# IBMManufactur
#
#
# {'is_watermarked': False, 'score': 1.0151725779206866}
#
#
# Natural text:
# .
# IBM on Tuesday announced a prepackaged and pretested cluster that is powered by Advanced Micro Devices Inc.s 64-bit Opteron processor.
# IBM, of Armonk, N.Y., is combining its Opteron-based eServer 325 server—which targets scientific and technical computing users—with systems management software and storage devices to offer a bundled package that can run Linux and Windows operating systems.
# The new offering, which will be available later this month or in early December, is part of IBMs eServer Cluster 1350, which also includes bundles based on the companys BladeCenter blade servers and two-processor x335 and x345 systems using Intel Corp.s 32-bit Xeon chips.
# Clusters comprise multiple servers tied together to create a supercomputing environment for users. In a related move, IBM last week announced that it was teaming with Corning Inc., the U.S. Department of Energy and the National Nuclear Security
#
#
# {'is_watermarked': False, 'score': 1.0024126694856696}

# %% [markdown]
# # 3. Mechanism Visualization

# %%
import torch
import gc
import json
from visualize.font_settings import FontSettings
from watermark.auto_watermark import AutoWatermark
from utils.transformers_config import TransformersConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
from visualize.page_layout_settings import PageLayoutSettings
from visualize.data_for_visualization import DataForVisualization
from visualize.visualizer import DiscreteVisualizer, ContinuousVisualizer
from visualize.legend_settings import DiscreteLegendSettings, ContinuousLegendSettings
from visualize.color_scheme import ColorSchemeForDiscreteVisualization, ColorSchemeForContinuousVisualization
from IPython.display import display
from PIL import Image, ImageOps, ImageFont, ImageDraw

def test_discreet_visualization():
    tokens = ["PREFIX", "PREFIX", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test"]
    flags = [-1, -1, 1, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0]
    weights = [0, 0, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4]

    discreet_visualizer = DiscreteVisualizer(color_scheme=ColorSchemeForDiscreteVisualization(),
                                            font_settings=FontSettings(),
                                            page_layout_settings=PageLayoutSettings(),
                                            legend_settings=DiscreteLegendSettings())
    img = discreet_visualizer.visualize(data=DataForVisualization(tokens, flags, weights),
                                     show_text=True, visualize_weight=True, display_legend=True)

    img.save("test1.png")
    display(img)


def test_continuous_visualization():
    tokens = ["PREFIX", "PREFIX", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test", "Hello", "world", "this", "is", "a", "test"]
    values = [None, None, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4]
    weights = [0, 0, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4, 0.1, 0.5, 0.3, 0.8, 0.2, 0.4]

    continuous_visualizer = ContinuousVisualizer(color_scheme=ColorSchemeForContinuousVisualization(),
                                                    font_settings=FontSettings(),
                                                    page_layout_settings=PageLayoutSettings(),
                                                    legend_settings=ContinuousLegendSettings())
    img = continuous_visualizer.visualize(data=DataForVisualization(tokens, values, weights),
                                        show_text=False, visualize_weight=False, display_legend=True)

    img.save("test2.png")
    display(img)


def get_data(algorithm_name):
    # Load data
    with open('dataset/c4/processed_c4.json', 'r') as f:
        lines = f.readlines()
    item = json.loads(lines[0])
    prompt = item['prompt']

    # Device
    device = "cuda" if torch.cuda.is_available() else "cpu"

    # Transformers config
    transformers_config = TransformersConfig(model=AutoModelForCausalLM.from_pretrained(opt_path).to(device),
                                            tokenizer=AutoTokenizer.from_pretrained(opt_path),
                                            vocab_size=50272,
                                            device=device,
                                            max_new_tokens=200,
                                            min_length=230,
                                            no_repeat_ngram_size=4)

    myWatermark = AutoWatermark.load(f'{algorithm_name}',
                                     algorithm_config=f'config/{algorithm_name}.json',
                                     transformers_config=transformers_config)

    prompt = '''
    public static void checkNumber(int number) {
        if (number > 0) {
            System.out.println("The number is positive.");
        }
        
        if (number < 0) {
            System.out.println("The number is negative.");
        }
        
        if (number == 0) {
            System.out.println("The number is zero.");
        }
    }
    '''

    watermarked_text = myWatermark.generate_watermarked_text(prompt)
    unwatermarked_text = myWatermark.generate_unwatermarked_text(prompt)
    watermarked_data = myWatermark.get_data_for_visualization(watermarked_text)
    unwatermarked_data = myWatermark.get_data_for_visualization(unwatermarked_text)

    return watermarked_data, unwatermarked_data


def test_visualization_without_weight(algorithm_name, visualize_type='discrete'):
    # Validate input
    assert visualize_type in ['discrete', 'continuous']
    if visualize_type == 'discrete':
        assert algorithm_name in ['KGW', 'Unigram', 'SWEET', 'UPV', 'SIR', 'XSIR', 'EWD', 'Custom']
    else:
        assert algorithm_name in ['EXP', 'EXPEdit']

    # Get data for visualization
    watermarked_data, unwatermarked_data = get_data(algorithm_name)

    # Init visualizer
    if visualize_type == 'discrete':
        visualizer = DiscreteVisualizer(color_scheme=ColorSchemeForDiscreteVisualization(),
                                        font_settings=FontSettings(),
                                        page_layout_settings=PageLayoutSettings(),
                                        legend_settings=DiscreteLegendSettings())
    else:
        visualizer = ContinuousVisualizer(color_scheme=ColorSchemeForContinuousVisualization(),
                                        font_settings=FontSettings(),
                                        page_layout_settings=PageLayoutSettings(),
                                        legend_settings=ContinuousLegendSettings())

    # Visualize
    watermarked_img = visualizer.visualize(data=watermarked_data,
                                           show_text=True,
                                           visualize_weight=True,
                                           display_legend=True)

    unwatermarked_img = visualizer.visualize(data=unwatermarked_data,
                                             show_text=True,
                                             visualize_weight=True,
                                             display_legend=True)

    watermarked_img.save(f"{algorithm_name}_watermarked.png")
    unwatermarked_img.save(f"{algorithm_name}_unwatermarked.png")

    watermarked_width, watermarked_height = watermarked_img.size
    unwatermarked_width, unwatermarked_height = unwatermarked_img.size

    font_size = 22
    font = ImageFont.truetype("./font/times.ttf", font_size)
    title_height = 80

    new_watermarked_img = Image.new('RGB', (watermarked_width, watermarked_height + title_height), (255, 255, 255))
    new_unwatermarked_img = Image.new('RGB', (unwatermarked_width, watermarked_height + title_height), (255, 255, 255))

    draw1 = ImageDraw.Draw(new_watermarked_img)
    text_bbox1 = draw1.textbbox((0, 0), f"{algorithm_name} watermarked", font=font)
    draw1.text((int((watermarked_width - text_bbox1[2] - text_bbox1[0]) * 0.3), int(title_height * 0.35)), f"{algorithm_name} watermarked", fill=(0, 0, 0), font=font)

    draw2 = ImageDraw.Draw(new_unwatermarked_img)
    text_bbox2 = draw2.textbbox((0, 0), f"{algorithm_name} unwatermarked", font=font)
    draw2.text((int((unwatermarked_width - text_bbox2[2] - text_bbox2[0]) * 0.3), int(title_height * 0.35)), f"{algorithm_name} unwatermarked", fill=(0, 0, 0), font=font)

    new_watermarked_img.paste(watermarked_img, (0, title_height))
    new_unwatermarked_img.paste(unwatermarked_img, (0, title_height))

    total_width = watermarked_width + unwatermarked_width
    max_height = watermarked_height + title_height

    new_img = Image.new('RGB', (total_width, max_height))

    new_img.paste(new_watermarked_img, (0, 0))
    new_img.paste(new_unwatermarked_img, (watermarked_width, 0))
    display(new_img)

def test_visualization_with_weight(algorithm_name):
    # Validate input
    assert algorithm_name in ['SWEET', 'EWD', 'Custom']

    # Get data for visualization
    watermarked_data, unwatermarked_data = get_data(algorithm_name)

    # Init visualizer
    visualizer = DiscreteVisualizer(color_scheme=ColorSchemeForDiscreteVisualization(),
                                    font_settings=FontSettings(),
                                    page_layout_settings=PageLayoutSettings(),
                                    legend_settings=DiscreteLegendSettings())

    # Visualize
    watermarked_img = visualizer.visualize(data=watermarked_data,
                                           show_text=True,
                                           visualize_weight=True,
                                           display_legend=True)

    unwatermarked_img = visualizer.visualize(data=unwatermarked_data,
                                             show_text=True,
                                             visualize_weight=True,
                                             display_legend=True)

    watermarked_img.save(f"{algorithm_name}_watermarked.png")
    unwatermarked_img.save(f"{algorithm_name}_unwatermarked.png")

    watermarked_width, watermarked_height = watermarked_img.size
    unwatermarked_width, unwatermarked_height = unwatermarked_img.size

    font_size = 22
    font = ImageFont.truetype("./font/times.ttf", font_size)
    title_height = 80

    new_watermarked_img = Image.new('RGB', (watermarked_width, watermarked_height + title_height), (255, 255, 255))
    new_unwatermarked_img = Image.new('RGB', (unwatermarked_width, watermarked_height + title_height), (255, 255, 255))

    draw1 = ImageDraw.Draw(new_watermarked_img)
    text_bbox1 = draw1.textbbox((0, 0), f"{algorithm_name} watermarked", font=font)
    draw1.text((int((watermarked_width - text_bbox1[2] - text_bbox1[0]) * 0.3), int(title_height * 0.35)), f"{algorithm_name} watermarked", fill=(0, 0, 0), font=font)

    draw2 = ImageDraw.Draw(new_unwatermarked_img)
    text_bbox2 = draw2.textbbox((0, 0), f"{algorithm_name} unwatermarked", font=font)
    draw2.text((int((unwatermarked_width - text_bbox2[2] - text_bbox2[0]) * 0.3), int(title_height * 0.35)), f"{algorithm_name} unwatermarked", fill=(0, 0, 0), font=font)

    new_watermarked_img.paste(watermarked_img, (0, title_height))
    new_unwatermarked_img.paste(unwatermarked_img, (0, title_height))

    total_width = watermarked_width + unwatermarked_width
    max_height = watermarked_height + title_height

    new_img = Image.new('RGB', (total_width, max_height))

    new_img.paste(new_watermarked_img, (0, 0))
    new_img.paste(new_unwatermarked_img, (watermarked_width, 0))
    display(new_img)

# %% [markdown]
# ## 3.1 Warm Up: Test Visualizer Using Provided Text

# %%
test_discreet_visualization()
# Out:
# <PIL.Image.Image image mode=RGB size=580x210>

# %%
test_continuous_visualization()
# Out:
# <PIL.Image.Image image mode=RGB size=580x210>

# %% [markdown]
# ## 3.2 Mechansim Visualization of Watermarking Algorithms

# %% [markdown]
# ### 3.2.1 KGW Family

# %%
test_visualization_without_weight('Custom', 'discrete')
# Out:
# <PIL.Image.Image image mode=RGB size=1160x2114>

# %% [markdown]
# ### 3.2.2 Christ Family

# %%
test_visualization_without_weight('EXP', 'continuous')
# Out:
# <PIL.Image.Image image mode=RGB size=1160x1734>

# %% [markdown]
# ### 3.2.3 Handling Weighted Token Difference in Visualization

# %%
test_visualization_with_weight('Custom')
# Out:
# <PIL.Image.Image image mode=RGB size=1160x2114>

# %%
test_visualization_with_weight('EWD')
# Out:
# <PIL.Image.Image image mode=RGB size=1160x1886>

# %% [markdown]
# # 4. Automated Comprehensive Evaluation

# %% [markdown]
# ## 4.1 Watermark Detection Pipeline

# %%
import torch
import json
from evaluation.dataset import C4Dataset
from watermark.auto_watermark import AutoWatermark
from utils.transformers_config import TransformersConfig
from evaluation.tools.success_rate_calculator import DynamicThresholdSuccessRateCalculator
from transformers import AutoModelForCausalLM, AutoTokenizer, T5Tokenizer, T5ForConditionalGeneration, BertTokenizer, BertForMaskedLM
from evaluation.pipelines.detection import WatermarkedTextDetectionPipeline, UnWatermarkedTextDetectionPipeline, DetectionPipelineReturnType
from evaluation.tools.text_editor import TruncatePromptTextEditor, TruncateTaskTextEditor, WordDeletion, SynonymSubstitution, ContextAwareSynonymSubstitution, GPTParaphraser, DipperParaphraser

device = 'cuda' if torch.cuda.is_available() else 'cpu'

if torch.cuda.is_available():
  gc.collect()
  torch.cuda.empty_cache()
  with torch.no_grad():
      torch.cuda.empty_cache()

def test_detection_pipeline(algorithm_name, attack_name):
    my_dataset = C4Dataset('dataset/c4/processed_c4.json')
    transformers_config = TransformersConfig(model=AutoModelForCausalLM.from_pretrained(opt_path).to(device),
                                             tokenizer=AutoTokenizer.from_pretrained(opt_path),
                                             vocab_size=50272,
                                             device=device,
                                             max_new_tokens=200,
                                             min_length=230,
                                             do_sample=True,
                                             no_repeat_ngram_size=4)

    my_watermark = AutoWatermark.load(f'{algorithm_name}', algorithm_config=f'config/{algorithm_name}.json', transformers_config=transformers_config)

    if attack_name == 'Word-D':
      attack = WordDeletion(ratio=0.3)
    elif attack_name == 'Word-S':
      attack = SynonymSubstitution(ratio=0.5)
    elif attack_name == 'Word-S(Context)':
      attack = ContextAwareSynonymSubstitution(ratio=0.5,
                                               tokenizer=BertTokenizer.from_pretrained('/data2/shared_model/bert-large-uncased'),
                                               model=BertForMaskedLM.from_pretrained('/data2/shared_model/bert-large-uncased').to(device))
    elif attack_name == 'Doc-P(GPT-3.5)':
        attack = GPTParaphraser(openai_model='gpt-3.5-turbo',
                                prompt='Please rewrite the following text: ')
    elif attack_name == 'Doc-P(Dipper)':
        attack = DipperParaphraser(tokenizer=T5Tokenizer.from_pretrained('/data2/shared_model/google/t5-v1_1-xxl/'),
                                   model=T5ForConditionalGeneration.from_pretrained('/data2/shared_model/kalpeshk2011/dipper-paraphraser-xxl/', device_map='auto'),
                                   lex_diversity=60, order_diversity=0, sent_interval=1,
                                   max_new_tokens=100, do_sample=True, top_p=0.75, top_k=None)


    pipline1 = WatermarkedTextDetectionPipeline(dataset=my_dataset, text_editor_list=[TruncatePromptTextEditor(), attack],
                                                show_progress=True, return_type=DetectionPipelineReturnType.SCORES)

    pipline2 = UnWatermarkedTextDetectionPipeline(dataset=my_dataset, text_editor_list=[TruncatePromptTextEditor()],
                                            show_progress=True, return_type=DetectionPipelineReturnType.SCORES)

    calculator = DynamicThresholdSuccessRateCalculator(labels=['TPR', 'F1'], rule='best')
    print(calculator.calculate(pipline1.evaluate(my_watermark), pipline2.evaluate(my_watermark)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 8
#       6 from evaluation.tools.success_rate_calculator import DynamicThresholdSuccessRateCalculator
#       7 from transformers import AutoModelForCausalLM, AutoTokenizer, T5Tokenizer, T5ForConditionalGeneration, BertTokenizer, BertForMaskedLM
# ----> 8 from evaluation.pipelines.detection import WatermarkedTextDetectionPipeline, UnWatermarkedTextDetectionPipeline, DetectionPipelineReturnType
#       9 from evaluation.tools.text_editor import TruncatePromptTextEditor, TruncateTaskTextEditor, WordDeletion, SynonymSubstitution, ContextAwareSynonymSubstitution, GPTParaphraser, DipperParaphraser
#      11 device = 'cuda' if torch.cuda.is_available() else 'cpu'
#
# File d:\uni\sem9\IPOW\MarkLLM-pwr\evaluation\pipelines\detection.py:24
#      22 from watermark.base import BaseWatermark
#      23 from evaluation.dataset import BaseDataset
# ---> 24 from evaluation.tools.text_editor import TextEditor
#      25 from exceptions.exceptions import InvalidTextSourceModeError
#      28 class DetectionPipelineReturnType(Enum):
#
# File d:\uni\sem9\IPOW\MarkLLM-pwr\evaluation\tools\text_editor.py:32
#      30 from nltk.tokenize import word_tokenize
#      31 from nltk.tokenize import sent_tokenize
# ---> 32 from utils.openai_utils import OpenAIAPI
#      33 from exceptions.exceptions import DiversityValueError
#      34 from evaluation.tools.oracle import QualityOracle
#
# File d:\uni\sem9\IPOW\MarkLLM-pwr\utils\openai_utils.py:21
#      19 import os
#      20 import time
# ---> 21 import openai
#      22 from exceptions.exceptions import OpenAIModelConfigurationError
#      25 class OpenAIAPI:
#
# File c:\Python311\Lib\site-packages\openai\__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NOT_GIVEN, Omit, NoneType, NotGiven, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File c:\Python311\Lib\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File c:\Python311\Lib\site-packages\openai\types\batch.py:7
#       4 from typing import List, Optional
#       5 from typing_extensions import Literal
# ----> 7 from .._models import BaseModel
#       8 from .batch_error import BatchError
#       9 from .batch_request_counts import BatchRequestCounts
#
# File c:\Python311\Lib\site-packages\openai\_models.py:7
#       5 from typing import TYPE_CHECKING, Any, Type, Tuple, Union, Generic, TypeVar, Callable, Optional, cast
#       6 from datetime import date, datetime
# ----> 7 from typing_extensions import (
#       8     Unpack,
#       9     Literal,
#      10     ClassVar,
#      11     Protocol,
#      12     Required,
#      13     Sequence,
#      14     ParamSpec,
#      15     TypedDict,
#      16     TypeGuard,
#      17     final,
#      18     override,
#      19     runtime_checkable,
#      20 )
#      22 import pydantic
#      23 import pydantic.generics
#
# ImportError: cannot import name 'Sequence' from 'typing_extensions' (c:\Python311\Lib\site-packages\typing_extensions.py)

# %%
test_detection_pipeline('Custom', 'Word-D')
# Out:
# Processing: 100%|█████████████████████████████████████████████████████████████| 200/200 [10:59<00:00,  3.30s/it]
# Processing: 100%|█████████████████████████████████████████████████████████████| 200/200 [00:08<00:00, 23.00it/s]
# {'TPR': 0.995, 'F1': 0.9974937343358395}

# %% [markdown]
# ## 4.2 Text Quality Analysis Pipeline

# %%
import torch
import json
from watermark.auto_watermark import AutoWatermark
from utils.transformers_config import TransformersConfig
from evaluation.dataset import C4Dataset, WMT16DE_ENDataset, HumanEvalDataset
from evaluation.tools.success_rate_calculator import DynamicThresholdSuccessRateCalculator
from transformers import AutoModelForCausalLM, AutoModelForSeq2SeqLM, AutoTokenizer, LlamaTokenizer
from evaluation.tools.text_editor import TruncatePromptTextEditor, TruncateTaskTextEditor ,CodeGenerationTextEditor
from evaluation.tools.text_quality_analyzer import PPLCalculator, LogDiversityAnalyzer, BLEUCalculator, PassOrNotJudger, GPTTextDiscriminator
from evaluation.pipelines.detection import WatermarkedTextDetectionPipeline, UnWatermarkedTextDetectionPipeline, DetectionPipelineReturnType
from evaluation.pipelines.quality_analysis import (DirectTextQualityAnalysisPipeline, ReferencedTextQualityAnalysisPipeline, ExternalDiscriminatorTextQualityAnalysisPipeline,
                                                   QualityPipelineReturnType)

device = 'cuda' if torch.cuda.is_available() else 'cpu'

if torch.cuda.is_available():
  gc.collect()
  torch.cuda.empty_cache()
  with torch.no_grad():
      torch.cuda.empty_cache()

def test_direct_quality_analysis_pipeline(algorithm_name, quality_analyzer_name):
    my_dataset = C4Dataset('dataset/c4/processed_c4.json')
    transformers_config = TransformersConfig(model=AutoModelForCausalLM.from_pretrained(opt_path).to(device),
                          tokenizer=AutoTokenizer.from_pretrained(opt_path),
                          vocab_size=50272,
                          device=device,
                          max_new_tokens=200,
                          min_length=230,
                          do_sample=True,
                          no_repeat_ngram_size=4)
    my_watermark = AutoWatermark.load(f'{algorithm_name}', algorithm_config=f'config/{algorithm_name}.json', transformers_config=transformers_config)

    if quality_analyzer_name == 'PPL':
      analyzer = PPLCalculator(model=AutoModelForCausalLM.from_pretrained(llama_path, device_map='auto'),
                                tokenizer=LlamaTokenizer.from_pretrained(llama_path),
                                device=device)
    elif quality_analyzer_name == 'Log Diversity':
      analyzer = LogDiversityAnalyzer()

    quality_pipeline = DirectTextQualityAnalysisPipeline(dataset=my_dataset,
                                watermarked_text_editor_list=[TruncatePromptTextEditor()],
                                unwatermarked_text_editor_list=[],
                                analyzer=analyzer,
                                unwatermarked_text_source='natural', show_progress=True,
                                return_type=QualityPipelineReturnType.MEAN_SCORES)

    print(f"{quality_analyzer_name}:")
    print(quality_pipeline.evaluate(my_watermark))


def test_referenced_quality_analysis_pipeline_1(algorithm_name):
    """Evaluate the impact on text quality in the machine translation task."""
    my_dataset = WMT16DE_ENDataset('dataset/wmt16_de_en/validation.jsonl')
    tokenizer= AutoTokenizer.from_pretrained(nllb_path, src_lang="deu_Latn")
    transformers_config = TransformersConfig(model=AutoModelForSeq2SeqLM.from_pretrained(nllb_path).to(device),
                                                tokenizer=tokenizer,
                                                device=device,
                                                forced_bos_token_id=tokenizer.lang_code_to_id["eng_Latn"])

    my_watermark = AutoWatermark.load(f'{algorithm_name}', algorithm_config=f'config/{algorithm_name}.json', transformers_config=transformers_config)

    quality_pipeline = ReferencedTextQualityAnalysisPipeline(dataset=my_dataset,
                                                              watermarked_text_editor_list=[],
                                                              unwatermarked_text_editor_list=[],
                                                              analyzer=BLEUCalculator(),
                                                              unwatermarked_text_source='generated', show_progress=True,
                                                              return_type=QualityPipelineReturnType.MEAN_SCORES)


    print("BLEU:")
    print(quality_pipeline.evaluate(my_watermark))


def test_referenced_quality_analysis_pipeline_2(algorithm_name):
    """Evaluate the impact on text quality in the code generation task."""
    my_dataset = HumanEvalDataset('dataset/human_eval/test.jsonl')
    tokenizer= AutoTokenizer.from_pretrained(tiny_starcoder_path)
    transformers_config = TransformersConfig(model=AutoModelForCausalLM.from_pretrained(tiny_starcoder_path, device_map='auto'),
                                             tokenizer=tokenizer,
                                             device=device,
                                             min_length=200,
                                             max_length=400)

    my_watermark = AutoWatermark.load(f'{algorithm_name}', algorithm_config=f'config/{algorithm_name}.json', transformers_config=transformers_config)

    quality_pipeline = ReferencedTextQualityAnalysisPipeline(dataset=my_dataset,
                                  watermarked_text_editor_list=[TruncateTaskTextEditor(),CodeGenerationTextEditor()],
                                  unwatermarked_text_editor_list=[TruncateTaskTextEditor(), CodeGenerationTextEditor()],
                                  analyzer=PassOrNotJudger(),
                                  unwatermarked_text_source='generated', show_progress=True,
                                  return_type=QualityPipelineReturnType.MEAN_SCORES)

    print("pass@1:")
    print(quality_pipeline.evaluate(my_watermark))


def test_discriminator_quality_analysis_pipeline(algorithm_name):
    my_dataset = WMT16DE_ENDataset('dataset/wmt16_de_en/validation.jsonl')
    tokenizer= AutoTokenizer.from_pretrained(nllb_path, src_lang="deu_Latn")
    transformers_config = TransformersConfig(model=AutoModelForSeq2SeqLM.from_pretrained(nllb_path).to(device),
                                                tokenizer=tokenizer,
                                                device=device,
                                                forced_bos_token_id=tokenizer.lang_code_to_id["eng_Latn"])

    my_watermark = AutoWatermark.load(f'{algorithm_name}', algorithm_config=f'config/{algorithm_name}.json', transformers_config=transformers_config)

    quality_pipeline = ExternalDiscriminatorTextQualityAnalysisPipeline(dataset=my_dataset,
                                      watermarked_text_editor_list=[],
                                      unwatermarked_text_editor_list=[],
                                      analyzer=GPTTextDiscriminator(openai_model='gpt-4',
                                      task_description='Translate the following German text to English'),
                                      unwatermarked_text_source='generated', show_progress=True,
                                      return_type=QualityPipelineReturnType.MEAN_SCORES
                                      )

    print("Win Rate:")
    print(quality_pipeline.evaluate(my_watermark))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 8
#       6 from evaluation.tools.success_rate_calculator import DynamicThresholdSuccessRateCalculator
#       7 from transformers import AutoModelForCausalLM, AutoModelForSeq2SeqLM, AutoTokenizer, LlamaTokenizer
# ----> 8 from evaluation.tools.text_editor import TruncatePromptTextEditor, TruncateTaskTextEditor ,CodeGenerationTextEditor
#       9 from evaluation.tools.text_quality_analyzer import PPLCalculator, LogDiversityAnalyzer, BLEUCalculator, PassOrNotJudger, GPTTextDiscriminator
#      10 from evaluation.pipelines.detection import WatermarkedTextDetectionPipeline, UnWatermarkedTextDetectionPipeline, DetectionPipelineReturnType
#
# File d:\uni\sem9\IPOW\MarkLLM-pwr\evaluation\tools\text_editor.py:32
#      30 from nltk.tokenize import word_tokenize
#      31 from nltk.tokenize import sent_tokenize
# ---> 32 from utils.openai_utils import OpenAIAPI
#      33 from exceptions.exceptions import DiversityValueError
#      34 from evaluation.tools.oracle import QualityOracle
#
# File d:\uni\sem9\IPOW\MarkLLM-pwr\utils\openai_utils.py:21
#      19 import os
#      20 import time
# ---> 21 import openai
#      22 from exceptions.exceptions import OpenAIModelConfigurationError
#      25 class OpenAIAPI:
#
# File c:\Python311\Lib\site-packages\openai\__init__.py:8
#       5 import os as _os
#       6 from typing_extensions import override
# ----> 8 from . import types
#       9 from ._types import NOT_GIVEN, Omit, NoneType, NotGiven, Transport, ProxiesTypes
#      10 from ._utils import file_from_path
#
# File c:\Python311\Lib\site-packages\openai\types\__init__.py:5
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
#       3 from __future__ import annotations
# ----> 5 from .batch import Batch as Batch
#       6 from .image import Image as Image
#       7 from .model import Model as Model
#
# File c:\Python311\Lib\site-packages\openai\types\batch.py:7
#       4 from typing import List, Optional
#       5 from typing_extensions import Literal
# ----> 7 from .._models import BaseModel
#       8 from .batch_error import BatchError
#       9 from .batch_request_counts import BatchRequestCounts
#
# File c:\Python311\Lib\site-packages\openai\_models.py:7
#       5 from typing import TYPE_CHECKING, Any, Type, Tuple, Union, Generic, TypeVar, Callable, Optional, cast
#       6 from datetime import date, datetime
# ----> 7 from typing_extensions import (
#       8     Unpack,
#       9     Literal,
#      10     ClassVar,
#      11     Protocol,
#      12     Required,
#      13     Sequence,
#      14     ParamSpec,
#      15     TypedDict,
#      16     TypeGuard,
#      17     final,
#      18     override,
#      19     runtime_checkable,
#      20 )
#      22 import pydantic
#      23 import pydantic.generics
#
# ImportError: cannot import name 'Sequence' from 'typing_extensions' (c:\Python311\Lib\site-packages\typing_extensions.py)

# %%
test_direct_quality_analysis_pipeline('KGW', 'PPL')

# %%
test_direct_quality_analysis_pipeline('Unigram', 'Log Diversity')

# %%
test_referenced_quality_analysis_pipeline_1('SIR')

# %%
test_referenced_quality_analysis_pipeline_2('Custom')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 test_referenced_quality_analysis_pipeline_2('Custom')
#
# NameError: name 'test_referenced_quality_analysis_pipeline_2' is not defined

# %%
import openai

openai.api_key = ""

test_discriminator_quality_analysis_pipeline('EWD')
